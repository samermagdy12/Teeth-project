# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

IMG_SIZE = 160
BATCH_SIZE = 16

train_dir = "/kaggle/input/teeth-ds/teeth_data_set/Training"
val_dir = "/kaggle/input/teeth-ds/teeth_data_set/Validation"

# =========================
# Data Augmentation (صح)
# =========================
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,  # بدل rescale

    rotation_range=10,
    width_shift_range=0.05,
    height_shift_range=0.05,
    zoom_range=0.15,
    brightness_range=[0.8,1.2],
    fill_mode="nearest"
)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input  # بدل rescale
)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

NUM_CLASSES = train_gen.num_classes

# =========================
# Model
# =========================
base_model = tf.keras.applications.EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.45)(x)  # مهم للأسنان
output = Dense(NUM_CLASSES, activation="softmax")(x)

model = Model(base_model.input, output)

# =========================
# Compile
# =========================
model.compile(
    optimizer=Adam(learning_rate=3e-5),  # أقل شوية
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
# Out:
# Found 3702 images belonging to 7 classes.
# Found 1058 images belonging to 7 classes.

# %%
dummy = tf.random.normal([1,160,160,3])
model(dummy)
# Out:
# <tf.Tensor: shape=(1, 7), dtype=float32, numpy=
# array([[0.11605404, 0.11926621, 0.31626377, 0.08307325, 0.08005494,
#         0.1469504 , 0.13833748]], dtype=float32)>

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# Callbacks 
callbacks = [

    EarlyStopping(
        monitor="val_accuracy",
        patience=4,
        restore_best_weights=True,
        verbose=1
    ),

    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.3,
        patience=2,
        min_lr=1e-6,
        verbose=1
    ),

    ModelCheckpoint(
        "best_teeth_model.keras",
        monitor="val_accuracy",
        save_best_only=True,
        verbose=1
    )
]

# Phase 1 (Feature Extraction)
base_model.trainable = False

model.compile(
    optimizer=Adam(learning_rate=3e-5), 
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=15,      
    callbacks=callbacks,
    verbose=1
)

# Phase 2 (Fine-Tuning)
base_model.trainable = True

for layer in base_model.layers[:-20]:
    layer.trainable = False

model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history_fine = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=15,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.1862 - loss: 2.0906
# Epoch 1: val_accuracy improved from -inf to 0.28922, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 65s 199ms/step - accuracy: 0.1863 - loss: 2.0904 - val_accuracy: 0.2892 - val_loss: 1.8258 - learning_rate: 3.0000e-05
# Epoch 2/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.2478 - loss: 1.8991
# Epoch 2: val_accuracy improved from 0.28922 to 0.35822, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 27s 117ms/step - accuracy: 0.2477 - loss: 1.8990 - val_accuracy: 0.3582 - val_loss: 1.6902 - learning_rate: 3.0000e-05
# Epoch 3/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.3037 - loss: 1.8168
# Epoch 3: val_accuracy improved from 0.35822 to 0.40454, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 119ms/step - accuracy: 0.3037 - loss: 1.8167 - val_accuracy: 0.4045 - val_loss: 1.5874 - learning_rate: 3.0000e-05
# Epoch 4/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.3288 - loss: 1.7210
# Epoch 4: val_accuracy improved from 0.40454 to 0.44802, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 27s 116ms/step - accuracy: 0.3289 - loss: 1.7208 - val_accuracy: 0.4480 - val_loss: 1.5054 - learning_rate: 3.0000e-05
# Epoch 5/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.3684 - loss: 1.6321
# Epoch 5: val_accuracy improved from 0.44802 to 0.47543, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 27s 117ms/step - accuracy: 0.3684 - loss: 1.6321 - val_accuracy: 0.4754 - val_loss: 1.4381 - learning_rate: 3.0000e-05
# Epoch 6/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.3902 - loss: 1.5793
# Epoch 6: val_accuracy improved from 0.47543 to 0.50189, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 27s 116ms/step - accuracy: 0.3903 - loss: 1.5792 - val_accuracy: 0.5019 - val_loss: 1.3814 - learning_rate: 3.0000e-05
# Epoch 7/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.4175 - loss: 1.5239
# Epoch 7: val_accuracy improved from 0.50189 to 0.52741, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 27s 116ms/step - accuracy: 0.4176 - loss: 1.5238 - val_accuracy: 0.5274 - val_loss: 1.3330 - learning_rate: 3.0000e-05
# Epoch 8/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4372 - loss: 1.4836
# Epoch 8: val_accuracy improved from 0.52741 to 0.55388, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 27s 118ms/step - accuracy: 0.4372 - loss: 1.4834 - val_accuracy: 0.5539 - val_loss: 1.2899 - learning_rate: 3.0000e-05
# Epoch 9/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.4742 - loss: 1.4158
# Epoch 9: val_accuracy improved from 0.55388 to 0.57656, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 30s 129ms/step - accuracy: 0.4743 - loss: 1.4157 - val_accuracy: 0.5766 - val_loss: 1.2521 - learning_rate: 3.0000e-05
# Epoch 10/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4953 - loss: 1.3623
# Epoch 10: val_accuracy improved from 0.57656 to 0.58979, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.4953 - loss: 1.3623 - val_accuracy: 0.5898 - val_loss: 1.2181 - learning_rate: 3.0000e-05
# Epoch 11/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5072 - loss: 1.3272
# Epoch 11: val_accuracy improved from 0.58979 to 0.59735, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 29s 126ms/step - accuracy: 0.5073 - loss: 1.3272 - val_accuracy: 0.5974 - val_loss: 1.1882 - learning_rate: 3.0000e-05
# Epoch 12/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5293 - loss: 1.2688
# Epoch 12: val_accuracy improved from 0.59735 to 0.60491, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 32s 136ms/step - accuracy: 0.5293 - loss: 1.2689 - val_accuracy: 0.6049 - val_loss: 1.1604 - learning_rate: 3.0000e-05
# Epoch 13/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5222 - loss: 1.2795
# Epoch 13: val_accuracy improved from 0.60491 to 0.62193, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.5223 - loss: 1.2795 - val_accuracy: 0.6219 - val_loss: 1.1363 - learning_rate: 3.0000e-05
# Epoch 14/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5269 - loss: 1.2764
# Epoch 14: val_accuracy improved from 0.62193 to 0.62854, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 31s 132ms/step - accuracy: 0.5269 - loss: 1.2762 - val_accuracy: 0.6285 - val_loss: 1.1125 - learning_rate: 3.0000e-05
# Epoch 15/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5579 - loss: 1.2204
# Epoch 15: val_accuracy improved from 0.62854 to 0.64083, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 119ms/step - accuracy: 0.5579 - loss: 1.2205 - val_accuracy: 0.6408 - val_loss: 1.0908 - learning_rate: 3.0000e-05
# Restoring model weights from the end of the best epoch: 15.
# Epoch 1/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.4406 - loss: 1.5271
# Epoch 1: val_accuracy did not improve from 0.64083
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 73s 217ms/step - accuracy: 0.4406 - loss: 1.5270 - val_accuracy: 0.6172 - val_loss: 1.1795 - learning_rate: 1.0000e-05
# Epoch 2/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5165 - loss: 1.3700
# Epoch 2: val_accuracy improved from 0.64083 to 0.65785, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 122ms/step - accuracy: 0.5165 - loss: 1.3698 - val_accuracy: 0.6578 - val_loss: 1.1109 - learning_rate: 1.0000e-05
# Epoch 3/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5655 - loss: 1.2568
# Epoch 3: val_accuracy improved from 0.65785 to 0.69754, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 122ms/step - accuracy: 0.5656 - loss: 1.2567 - val_accuracy: 0.6975 - val_loss: 1.0280 - learning_rate: 1.0000e-05
# Epoch 4/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6148 - loss: 1.1642
# Epoch 4: val_accuracy improved from 0.69754 to 0.72023, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 121ms/step - accuracy: 0.6149 - loss: 1.1641 - val_accuracy: 0.7202 - val_loss: 0.9505 - learning_rate: 1.0000e-05
# Epoch 5/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6308 - loss: 1.1188
# Epoch 5: val_accuracy improved from 0.72023 to 0.73251, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 119ms/step - accuracy: 0.6308 - loss: 1.1187 - val_accuracy: 0.7325 - val_loss: 0.8861 - learning_rate: 1.0000e-05
# Epoch 6/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6875 - loss: 1.0087
# Epoch 6: val_accuracy improved from 0.73251 to 0.74764, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.6874 - loss: 1.0087 - val_accuracy: 0.7476 - val_loss: 0.8289 - learning_rate: 1.0000e-05
# Epoch 7/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6638 - loss: 1.0056
# Epoch 7: val_accuracy improved from 0.74764 to 0.75898, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.6639 - loss: 1.0055 - val_accuracy: 0.7590 - val_loss: 0.7804 - learning_rate: 1.0000e-05
# Epoch 8/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6973 - loss: 0.9290
# Epoch 8: val_accuracy improved from 0.75898 to 0.77032, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.6973 - loss: 0.9290 - val_accuracy: 0.7703 - val_loss: 0.7353 - learning_rate: 1.0000e-05
# Epoch 9/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7212 - loss: 0.8957
# Epoch 9: val_accuracy improved from 0.77032 to 0.78166, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.7212 - loss: 0.8956 - val_accuracy: 0.7817 - val_loss: 0.6951 - learning_rate: 1.0000e-05
# Epoch 10/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7489 - loss: 0.8265
# Epoch 10: val_accuracy improved from 0.78166 to 0.78922, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.7488 - loss: 0.8266 - val_accuracy: 0.7892 - val_loss: 0.6591 - learning_rate: 1.0000e-05
# Epoch 11/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.7415 - loss: 0.8094
# Epoch 11: val_accuracy improved from 0.78922 to 0.80057, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 119ms/step - accuracy: 0.7415 - loss: 0.8094 - val_accuracy: 0.8006 - val_loss: 0.6222 - learning_rate: 1.0000e-05
# Epoch 12/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.7796 - loss: 0.7466
# Epoch 12: val_accuracy improved from 0.80057 to 0.81096, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.7796 - loss: 0.7466 - val_accuracy: 0.8110 - val_loss: 0.5891 - learning_rate: 1.0000e-05
# Epoch 13/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.7629 - loss: 0.7444
# Epoch 13: val_accuracy improved from 0.81096 to 0.82892, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 66s 287ms/step - accuracy: 0.7629 - loss: 0.7443 - val_accuracy: 0.8289 - val_loss: 0.5586 - learning_rate: 1.0000e-05
# Epoch 14/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7808 - loss: 0.7083
# Epoch 14: val_accuracy improved from 0.82892 to 0.83743, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 77s 334ms/step - accuracy: 0.7807 - loss: 0.7083 - val_accuracy: 0.8374 - val_loss: 0.5307 - learning_rate: 1.0000e-05
# Epoch 15/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7955 - loss: 0.6789
# Epoch 15: val_accuracy improved from 0.83743 to 0.84783, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 121ms/step - accuracy: 0.7954 - loss: 0.6789 - val_accuracy: 0.8478 - val_loss: 0.5047 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 15.

# %%
history_fine = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=30, 
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8061 - loss: 0.6447
# Epoch 1: val_accuracy improved from 0.84783 to 0.84972, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 121ms/step - accuracy: 0.8061 - loss: 0.6447 - val_accuracy: 0.8497 - val_loss: 0.4767 - learning_rate: 1.0000e-05
# Epoch 2/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8105 - loss: 0.6202
# Epoch 2: val_accuracy improved from 0.84972 to 0.85917, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 122ms/step - accuracy: 0.8105 - loss: 0.6202 - val_accuracy: 0.8592 - val_loss: 0.4546 - learning_rate: 1.0000e-05
# Epoch 3/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8140 - loss: 0.6138
# Epoch 3: val_accuracy improved from 0.85917 to 0.86578, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.8141 - loss: 0.6137 - val_accuracy: 0.8658 - val_loss: 0.4298 - learning_rate: 1.0000e-05
# Epoch 4/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8297 - loss: 0.5824
# Epoch 4: val_accuracy improved from 0.86578 to 0.87713, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 121ms/step - accuracy: 0.8297 - loss: 0.5824 - val_accuracy: 0.8771 - val_loss: 0.4086 - learning_rate: 1.0000e-05
# Epoch 5/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8327 - loss: 0.5571
# Epoch 5: val_accuracy improved from 0.87713 to 0.88091, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 119ms/step - accuracy: 0.8326 - loss: 0.5571 - val_accuracy: 0.8809 - val_loss: 0.3864 - learning_rate: 1.0000e-05
# Epoch 6/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8431 - loss: 0.5183
# Epoch 6: val_accuracy improved from 0.88091 to 0.89414, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 29s 123ms/step - accuracy: 0.8431 - loss: 0.5183 - val_accuracy: 0.8941 - val_loss: 0.3660 - learning_rate: 1.0000e-05
# Epoch 7/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8538 - loss: 0.5144
# Epoch 7: val_accuracy improved from 0.89414 to 0.90076, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 30s 128ms/step - accuracy: 0.8539 - loss: 0.5143 - val_accuracy: 0.9008 - val_loss: 0.3458 - learning_rate: 1.0000e-05
# Epoch 8/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8606 - loss: 0.5023
# Epoch 8: val_accuracy improved from 0.90076 to 0.90832, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 122ms/step - accuracy: 0.8606 - loss: 0.5023 - val_accuracy: 0.9083 - val_loss: 0.3312 - learning_rate: 1.0000e-05
# Epoch 9/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8455 - loss: 0.5093
# Epoch 9: val_accuracy improved from 0.90832 to 0.91399, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.8456 - loss: 0.5092 - val_accuracy: 0.9140 - val_loss: 0.3140 - learning_rate: 1.0000e-05
# Epoch 10/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8486 - loss: 0.4992
# Epoch 10: val_accuracy improved from 0.91399 to 0.91588, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 121ms/step - accuracy: 0.8487 - loss: 0.4991 - val_accuracy: 0.9159 - val_loss: 0.3001 - learning_rate: 1.0000e-05
# Epoch 11/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8661 - loss: 0.4560
# Epoch 11: val_accuracy improved from 0.91588 to 0.92628, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 119ms/step - accuracy: 0.8661 - loss: 0.4560 - val_accuracy: 0.9263 - val_loss: 0.2824 - learning_rate: 1.0000e-05
# Epoch 12/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8824 - loss: 0.4207
# Epoch 12: val_accuracy improved from 0.92628 to 0.92911, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.8823 - loss: 0.4207 - val_accuracy: 0.9291 - val_loss: 0.2706 - learning_rate: 1.0000e-05
# Epoch 13/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8806 - loss: 0.3993
# Epoch 13: val_accuracy improved from 0.92911 to 0.93478, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.8806 - loss: 0.3993 - val_accuracy: 0.9348 - val_loss: 0.2553 - learning_rate: 1.0000e-05
# Epoch 14/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8765 - loss: 0.4234
# Epoch 14: val_accuracy improved from 0.93478 to 0.93667, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 121ms/step - accuracy: 0.8765 - loss: 0.4233 - val_accuracy: 0.9367 - val_loss: 0.2436 - learning_rate: 1.0000e-05
# Epoch 15/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8935 - loss: 0.3847
# Epoch 15: val_accuracy improved from 0.93667 to 0.94140, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 122ms/step - accuracy: 0.8935 - loss: 0.3847 - val_accuracy: 0.9414 - val_loss: 0.2318 - learning_rate: 1.0000e-05
# Epoch 16/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8857 - loss: 0.3930
# Epoch 16: val_accuracy improved from 0.94140 to 0.94802, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.8857 - loss: 0.3930 - val_accuracy: 0.9480 - val_loss: 0.2196 - learning_rate: 1.0000e-05
# Epoch 17/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9040 - loss: 0.3556
# Epoch 17: val_accuracy improved from 0.94802 to 0.95274, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.9040 - loss: 0.3556 - val_accuracy: 0.9527 - val_loss: 0.2078 - learning_rate: 1.0000e-05
# Epoch 18/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8951 - loss: 0.3496
# Epoch 18: val_accuracy improved from 0.95274 to 0.95747, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 119ms/step - accuracy: 0.8951 - loss: 0.3496 - val_accuracy: 0.9575 - val_loss: 0.1983 - learning_rate: 1.0000e-05
# Epoch 19/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9048 - loss: 0.3266
# Epoch 19: val_accuracy improved from 0.95747 to 0.95841, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 119ms/step - accuracy: 0.9048 - loss: 0.3266 - val_accuracy: 0.9584 - val_loss: 0.1892 - learning_rate: 1.0000e-05
# Epoch 20/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9133 - loss: 0.3193
# Epoch 20: val_accuracy improved from 0.95841 to 0.96219, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.9133 - loss: 0.3193 - val_accuracy: 0.9622 - val_loss: 0.1810 - learning_rate: 1.0000e-05
# Epoch 21/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9152 - loss: 0.3029
# Epoch 21: val_accuracy improved from 0.96219 to 0.96503, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 120ms/step - accuracy: 0.9152 - loss: 0.3030 - val_accuracy: 0.9650 - val_loss: 0.1725 - learning_rate: 1.0000e-05
# Epoch 22/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9059 - loss: 0.3278
# Epoch 22: val_accuracy did not improve from 0.96503
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 27s 117ms/step - accuracy: 0.9060 - loss: 0.3277 - val_accuracy: 0.9650 - val_loss: 0.1616 - learning_rate: 1.0000e-05
# Epoch 23/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9168 - loss: 0.2935
# Epoch 23: val_accuracy did not improve from 0.96503
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 27s 118ms/step - accuracy: 0.9168 - loss: 0.2935 - val_accuracy: 0.9650 - val_loss: 0.1556 - learning_rate: 1.0000e-05
# Epoch 24/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9244 - loss: 0.2816
# Epoch 24: val_accuracy improved from 0.96503 to 0.96881, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 121ms/step - accuracy: 0.9244 - loss: 0.2816 - val_accuracy: 0.9688 - val_loss: 0.1494 - learning_rate: 1.0000e-05
# Epoch 25/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9254 - loss: 0.2760
# Epoch 25: val_accuracy did not improve from 0.96881
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 27s 117ms/step - accuracy: 0.9254 - loss: 0.2760 - val_accuracy: 0.9679 - val_loss: 0.1420 - learning_rate: 1.0000e-05
# Epoch 26/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9270 - loss: 0.2717
# Epoch 26: val_accuracy did not improve from 0.96881
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 119ms/step - accuracy: 0.9270 - loss: 0.2717 - val_accuracy: 0.9688 - val_loss: 0.1371 - learning_rate: 1.0000e-05
# Epoch 27/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9188 - loss: 0.2759
# Epoch 27: val_accuracy improved from 0.96881 to 0.96975, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 121ms/step - accuracy: 0.9189 - loss: 0.2758 - val_accuracy: 0.9698 - val_loss: 0.1312 - learning_rate: 1.0000e-05
# Epoch 28/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9357 - loss: 0.2590
# Epoch 28: val_accuracy improved from 0.96975 to 0.97164, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 30s 129ms/step - accuracy: 0.9357 - loss: 0.2589 - val_accuracy: 0.9716 - val_loss: 0.1235 - learning_rate: 1.0000e-05
# Epoch 29/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9452 - loss: 0.2311
# Epoch 29: val_accuracy did not improve from 0.97164
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 44s 190ms/step - accuracy: 0.9452 - loss: 0.2311 - val_accuracy: 0.9716 - val_loss: 0.1176 - learning_rate: 1.0000e-05
# Epoch 30/30
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9350 - loss: 0.2497
# Epoch 30: val_accuracy improved from 0.97164 to 0.97732, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 44s 191ms/step - accuracy: 0.9350 - loss: 0.2497 - val_accuracy: 0.9773 - val_loss: 0.1124 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 30.

# %%
history_fine = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=15, 
    callbacks=callbacks
)
# Out:
# Epoch 1/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9500 - loss: 0.2273
# Epoch 1: val_accuracy improved from 0.97732 to 0.97921, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 30s 128ms/step - accuracy: 0.9500 - loss: 0.2273 - val_accuracy: 0.9792 - val_loss: 0.1084 - learning_rate: 1.0000e-05
# Epoch 2/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9460 - loss: 0.2173
# Epoch 2: val_accuracy improved from 0.97921 to 0.98110, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 30s 127ms/step - accuracy: 0.9460 - loss: 0.2173 - val_accuracy: 0.9811 - val_loss: 0.1014 - learning_rate: 1.0000e-05
# Epoch 3/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9439 - loss: 0.2198
# Epoch 3: val_accuracy improved from 0.98110 to 0.98204, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 29s 127ms/step - accuracy: 0.9439 - loss: 0.2198 - val_accuracy: 0.9820 - val_loss: 0.0966 - learning_rate: 1.0000e-05
# Epoch 4/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9455 - loss: 0.2045
# Epoch 4: val_accuracy improved from 0.98204 to 0.98393, saving model to best_teeth_model.keras
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 29s 124ms/step - accuracy: 0.9456 - loss: 0.2045 - val_accuracy: 0.9839 - val_loss: 0.0919 - learning_rate: 1.0000e-05
# Epoch 5/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9513 - loss: 0.1882
# Epoch 5: val_accuracy did not improve from 0.98393
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 121ms/step - accuracy: 0.9513 - loss: 0.1882 - val_accuracy: 0.9839 - val_loss: 0.0896 - learning_rate: 1.0000e-05
# Epoch 6/15
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9592 - loss: 0.1923
# Epoch 6: val_accuracy did not improve from 0.98393
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 28s 122ms/step - accuracy: 0.9591 - loss: 0.1923 - val_accuracy: 0.9839 - val_loss: 0.0853 - learning_rate: 1.0000e-05
# Epoch 7/15
#  93/232 ━━━━━━━━━━━━━━━━━━━━ 15s 114ms/step - accuracy: 0.9420 - loss: 0.2139
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_55/775815818.py in <cell line: 0>()
# ----> 1 history_fine = model.fit(
#       2     train_gen,
#       3     validation_data=val_gen,
#       4     epochs=15,  # بدل 15
#       5     callbacks=callbacks
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375                 for step, iterator in epoch_iterator:
#     376                     callbacks.on_train_batch_begin(step)
# --> 377                     logs = self.train_function(iterator)
#     378                     callbacks.on_train_batch_end(step, logs)
#     379                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     218                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219             ):
# --> 220                 opt_outputs = multi_step_on_iterator(iterator)
#     221                 if not opt_outputs.has_value():
#     222                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

preds = best_model.predict(test_gen)
y_pred = np.argmax(preds, axis=1)

print(classification_report(test_gen.classes, y_pred))
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 201ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        80
#            1       0.99      1.00      0.99        76
#            2       1.00      1.00      1.00        71
#            3       0.97      0.96      0.97        80
#            4       0.93      0.97      0.95        70
#            5       0.95      0.96      0.96        80
#            6       1.00      0.97      0.99        76
#
#     accuracy                           0.98       533
#    macro avg       0.98      0.98      0.98       533
# weighted avg       0.98      0.98      0.98       533
